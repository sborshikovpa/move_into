# %% [markdown]
# # 05. Практические задачи по темам
#
# Задачи сгруппированы по основным темам курса. Решай их в отдельных `.py` файлах или в ноутбуке. Сначала добейся рабочего решения, потом попробуй сделать код короче и понятнее.

# %%
# ????? ??????? ? ?????????, ???? ???????????

# %% [markdown]
# ## 01. Основы Python

# %% [markdown]
# ### 1. Калькулятор секунд
#
# Напиши программу, которая считает:
#
# - сколько секунд в одном дне;
# - сколько секунд в обычном году;
# - сколько секунд в високосном году.
#
# Результат выведи понятными строками через `print()`.

# %%
# ???????

# %% [markdown]
# ### 2. Конвертер возраста
#
# Пользователь вводит возраст в годах. Программа выводит примерный возраст:
#
# - в днях;
# - в часах;
# - в минутах.
#
# Считай, что в году 365 дней.

# %%
# ???????

# %% [markdown]
# ### 3. Проверка числа
#
# Пользователь вводит целое число. Выведи:
#
# - четное оно или нечетное;
# - положительное, отрицательное или ноль;
# - делится ли оно на `3` и на `5` одновременно.

# %%
# ???????

# %% [markdown]
# ### 4. Мини-анкета
#
# Спроси у пользователя имя, возраст и город. Сохрани данные в словарь и выведи строку:
#
# ```text
# Меня зовут <имя>, мне <возраст>, я из города <город>.
# ```

# %%
# ???????

# %% [markdown]
# ### 5. Работа со списком покупок
#
# Создай список покупок из 5 элементов. Затем:
#
# - добавь еще 2 элемента;
# - удали последний элемент;
# - выведи первые 3 покупки;
# - проверь, есть ли в списке `"молоко"`.

# %%
# ???????

# %% [markdown]
# ### 6. Срезы строки
#
# Пользователь вводит слово. Выведи:
#
# - первую букву;
# - последнюю букву;
# - первые 3 буквы;
# - слово наоборот.

# %%
# ???????

# %% [markdown]
# ### 7. Таблица квадратов
#
# Выведи квадраты чисел от `1` до `20`.
#
# Формат строки:
#
# ```text
# 7 -> 49
# ```

# %%
# ???????

# %% [markdown]
# ### 8. Високосные годы
#
# Выведи все високосные годы от `1900` до `2100`.
#
# Год високосный, если он делится на `4`, но не делится на `100`, кроме случаев, когда делится на `400`.

# %%
# ???????

# %% [markdown]
# ### 9. Угадай число
#
# Задай в коде секретное число. Пользователь вводит числа, пока не угадает.
#
# После каждой попытки выводи:
#
# - `"больше"`, если секретное число больше;
# - `"меньше"`, если секретное число меньше;
# - `"угадал"`, если число найдено.

# %%
# ???????

# %% [markdown]
# ### 10. Функция приветствия
#
# Напиши функцию `get_greeting(name, age)`, которая возвращает строку:
#
# ```text
# Привет, <name>! Тебе <age> лет.
# ```
#
# Проверь функцию на нескольких разных именах.

# %%
# ???????

# %% [markdown]
# ## 02. Архитектура проекта и первые классы

# %% [markdown]
# ### 1. Модуль с математикой
#
# Создай файл `math_utils.py` с функциями:
#
# - `add(a, b)`;
# - `multiply(a, b)`;
# - `is_even(number)`.
#
# В другом файле импортируй эти функции и проверь их работу.

# %%
# ???????

# %% [markdown]
# ### 2. Конфиг игрового поля
#
# Создай `config.py` с константами:
#
# ```python
# MAP_WIDTH = 10
# MAP_HEIGHT = 5
# EMPTY_SYMBOL = "."
# PLAYER_SYMBOL = "@"
# ```
#
# В основном файле импортируй их и выведи пустое поле заданного размера.

# %%
# ???????

# %% [markdown]
# ### 3. Класс `Point`
#
# Создай класс `Point`, который хранит `x` и `y`.
#
# Добавь методы:
#
# - `move(dx, dy)`;
# - `as_tuple()`;
# - `is_zero()`.

# %%
# ???????

# %% [markdown]
# ### 4. Класс `Player`
#
# Создай класс `Player` с атрибутами:
#
# - `name`;
# - `hp`;
# - `x`;
# - `y`.
#
# Добавь методы:
#
# - `move(dx, dy)`;
# - `take_damage(amount)`;
# - `is_alive()`.

# %%
# ???????

# %% [markdown]
# ### 5. Атака персонажей
#
# Создай класс `Character` с `name`, `hp`, `damage`.
#
# Метод `attack(target)` должен уменьшать здоровье цели на величину `damage`.
#
# Проверь бой двух персонажей в несколько ходов.

# %%
# ???????

# %% [markdown]
# ### 6. Инкапсуляция здоровья
#
# Переделай `Character` так, чтобы здоровье хранилось в `_hp`.
#
# Добавь методы:
#
# - `get_hp()`;
# - `heal(amount)`;
# - `take_damage(amount)`.
#
# Здоровье не должно становиться меньше `0`.

# %%
# ???????

# %% [markdown]
# ### 7. Базовый класс `Entity`
#
# Создай базовый класс `Entity` с `x`, `y`, `symbol`.
#
# От него унаследуй:
#
# - `Player`;
# - `Wall`;
# - `Coin`.
#
# Напиши функцию `draw_entities(entities)`, которая выводит координаты и символ каждой сущности.

# %%
# ???????

# %% [markdown]
# ### 8. Предмет лечения
#
# Создай класс `HealingPotion`, который наследуется от `Entity`.
#
# У него должен быть метод `apply(target)`, который лечит цель.
#
# Проверь на объекте `Player`.

# %%
# ???????

# %% [markdown]
# ### 9. Проверка клетки
#
# В `Entity` добавь метод `is_at(x, y)`, который возвращает `True`, если объект стоит в этих координатах.
#
# Используй его, чтобы найти все сущности на клетке `(2, 3)`.

# %%
# ???????

# %% [markdown]
# ### 10. Мини-проект: карта
#
# Собери маленькую программу:
#
# - есть список сущностей;
# - есть игрок;
# - игрок может двигаться;
# - после каждого движения выводятся координаты всех сущностей;
# - если игрок оказался на клетке с монетой, монета исчезает.

# %%
# ???????

# %% [markdown]
# ## 03. Продвинутый Python

# %% [markdown]
# ### 1. Уникальные слова
#
# Дана строка с текстом. Нужно вывести количество уникальных слов.
#
# Слова можно получить через `.split()`. Регистр можно привести к нижнему через `.lower()`.

# %%
# ???????

# %% [markdown]
# ### 2. Общие интересы
#
# Есть два множества интересов двух людей.
#
# Выведи:
#
# - общие интересы;
# - все интересы без повторов;
# - интересы первого, которых нет у второго;
# - интересы второго, которых нет у первого.

# %%
# ???????

# %% [markdown]
# ### 3. Поиск анаграмм
#
# Дан список слов и выбранное слово.
#
# Найди все слова из списка, которые состоят из тех же букв, что и выбранное слово.
#
# Пример: `listen` и `silent`.

# %%
# ???????

# %% [markdown]
# ### 4. Фильтр через comprehension
#
# Дан список чисел от `1` до `100`.
#
# Создай через list comprehension:
#
# - список квадратов четных чисел;
# - список чисел, которые делятся на `3` или `5`;
# - список строк `"even"` или `"odd"` для каждого числа.

# %%
# ???????

# %% [markdown]
# ### 5. Словарь квадратов
#
# Создай словарь, где ключи это числа от `1` до `20`, а значения это их квадраты.
#
# Сделай это через dict comprehension.

# %%
# ???????

# %% [markdown]
# ### 6. Безопасное чтение словаря
#
# Дан словарь пользователя:
#
# ```python
# user = {"name": "Ann", "age": 25}
# ```
#
# Попробуй получить ключ `"city"` через `try-except`. Если ключа нет, сохрани значение `"unknown"`.
#
# Потом реши то же самое через `.get()`.

# %%
# ???????

# %% [markdown]
# ### 7. Опасный default argument
#
# Напиши функцию `append_tag(tag, tags=[])`, которая добавляет тег в список.
#
# Вызови ее несколько раз и посмотри, почему это опасно.
#
# Затем исправь функцию через `None`.

# %%
# ???????

# %% [markdown]
# ### 8. Кортеж пользователя
#
# Функция `get_user()` должна возвращать кортеж из трех значений:
#
# - имя;
# - возраст;
# - город.
#
# Вызови функцию и распакуй результат в три переменные.

# %%
# ???????

# %% [markdown]
# ### 9. Фильтр кортежей
#
# Дан список:
#
# ```python
# tuples = [(), (1, 2), (), ("a",), (3, 4, 5)]
# ```
#
# Создай новый список только из непустых кортежей.

# %%
# ???????

# %% [markdown]
# ### 10. Индекс слов
#
# Дан список слов. Создай словарь, где ключ это первая буква, а значение это множество слов на эту букву.
#
# Пример:
#
# ```python
# ["cat", "car", "dog"] -> {"c": {"cat", "car"}, "d": {"dog"}}
# ```

# %%
# ???????

# %% [markdown]
# ## 04. ООП: полиморфизм, dunder-методы, фабрика

# %% [markdown]
# ### 1. Голоса животных
#
# Создай базовый класс `Animal` и классы `Dog`, `Cat`, `Cow`.
#
# У каждого должен быть метод `speak()`.
#
# Создай список животных и вызови `speak()` у каждого в цикле.

# %%
# ???????

# %% [markdown]
# ### 2. Утиная типизация
#
# Создай классы:
#
# - `Bird` с методом `fly()`;
# - `Plane` с методом `fly()`;
# - `Fish` без метода `fly()`.
#
# Напиши функцию `make_it_fly(obj)`, которая вызывает `obj.fly()`.
#
# Проверь, что будет с `Fish`.

# %%
# ???????

# %% [markdown]
# ### 3. Площадь фигур
#
# Создай классы `Rectangle`, `Circle`, `Triangle`.
#
# У каждого должен быть метод `area()`.
#
# Собери фигуры в список и выведи площадь каждой.

# %%
# ???????

# %% [markdown]
# ### 4. Красивый вывод `Person`
#
# Создай класс `Person` с `name` и `age`.
#
# Реализуй `__str__`, чтобы `print(person)` выводил:
#
# ```text
# Person(name=Ann, age=25)
# ```

# %%
# ???????

# %% [markdown]
# ### 5. Сложение кошельков
#
# Создай класс `Wallet` с количеством денег.
#
# Реализуй:
#
# - `__add__`, чтобы можно было складывать два кошелька;
# - `__str__`, чтобы красиво печатать результат.

# %%
# ???????

# %% [markdown]
# ### 6. Сравнение товаров
#
# Создай класс `Product` с `name` и `price`.
#
# Реализуй `__lt__`, чтобы товары можно было сортировать по цене через `sorted(products)`.

# %%
# ???????

# %% [markdown]
# ### 7. Вектор
#
# Создай класс `Vector` с `x` и `y`.
#
# Реализуй:
#
# - `__add__`;
# - `__sub__`;
# - `__str__`;
# - `__eq__`.
#
# Проверь сложение, вычитание и сравнение двух векторов.

# %%
# ???????

# %% [markdown]
# ### 8. Коллекция задач
#
# Создай класс `TodoList`, который хранит список задач.
#
# Реализуй:
#
# - `add(task)`;
# - `__len__`;
# - `__iter__`;
# - `__str__`.
#
# После этого объект должен работать с `len(todo)` и в цикле `for`.

# %%
# ???????

# %% [markdown]
# ### 9. Фабрика уведомлений
#
# Создай базовый класс `Notifier` с методом `send(message)`.
#
# Создай наследников:
#
# - `EmailNotifier`;
# - `SmsNotifier`;
# - `TelegramNotifier`.
#
# Создай фабрику `NotifierFactory`, которая по строке `"email"`, `"sms"` или `"telegram"` возвращает нужный объект.

# %%
# ???????

# %% [markdown]
# ### 10. Фабрика игровых противников
#
# Создай классы противников:
#
# - `ScoutEnemy`;
# - `TankEnemy`;
# - `BossEnemy`.
#
# У каждого должен быть метод `attack()`.
#
# Создай фабрику `EnemyFactory`, которая по строке создает нужного противника. Если тип неизвестен, выбрасывай `ValueError`.

# %%
# ???????
