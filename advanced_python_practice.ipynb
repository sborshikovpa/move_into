# %% [markdown]
# # Практика по продвинутому Python
# Задачи по аналогии с конспектом.

# %% [markdown]
# ## Задача 1. Контекстный менеджер
# Реализуй контекстный менеджер Logger, который печатает вход и выход из блока with.

# %%
# Твоё решение здесь

# %% [markdown]
# ## Задача 2. JSON
# Сохрани список книг в JSON и прочитай его обратно.

# %%
# Твоё решение здесь

# %% [markdown]
# ## Задача 3. sorted
# Отсортируй список словарей сотрудников по зарплате и имени.

# %%
# Твоё решение здесь

# %% [markdown]
# ## Задача 4. lambda
# Напиши lambda, возвращающую куб числа.

# %%
# Твоё решение здесь

# %% [markdown]
# ## Задача 5. map/filter
# Оставь только строки длиной больше 5 и переведи их в верхний регистр.

# %%
# Твоё решение здесь

# %% [markdown]
# ## Задача 6. Декоратор
# Напиши декоратор timer, измеряющий время выполнения функции.

# %%
# Твоё решение здесь

# %% [markdown]
# ## Задача 7. Итератор
# Создай итератор OddNumbers, возвращающий только нечётные числа.

# %%
# Твоё решение здесь

# %% [markdown]
# ## Задача 8. Генератор
# Напиши генератор countdown(n), который считает от n до 1.

# %%
# Твоё решение здесь

# %% [markdown]
# ## Задача 9. Генераторное выражение
# Посчитай сумму квадратов чисел, кратных 3, от 1 до 100000.

# %%
# Твоё решение здесь

# %% [markdown]
# ## Задача 10. __main__
# Создай файл с функцией main() и блоком if __name__ == "__main__".

# %%
# Твоё решение здесь
