# %% [markdown]
# # 07. Практика по очень продвинутому Python
#
# Здесь задачи по темам из ноутбука `python_6_advanced+.ipynb`. В каждой теме по 5 задач. Решай их в ноутбуке или `.py` файлах; готовые решения лучше писать отдельно, чтобы не подглядывать.

# %%
# ????? ??????? ? ?????????, ???? ???????????

# %% [markdown]
# ## Менеджеры контекста `with`

# %% [markdown]
# ### 1. Безопасная запись в файл
#
# Создай список строк и запиши их в файл `notes.txt`, используя `with open(...)`.
#
# Потом открой этот же файл через `with` и выведи его содержимое.

# %%
# ???????

# %% [markdown]
# ### 2. JSON-конфиг
#
# Создай словарь с настройками приложения:
#
# ```python
# config = {
#     "theme": "dark",
#     "language": "ru",
#     "autosave": True,
#     "font_size": 14,
# }
# ```
#
# Сохрани его в `config.json`, а затем прочитай обратно.

# %%
# ???????

# %% [markdown]
# ### 3. Контекстный менеджер `Timer`
#
# Напиши класс `Timer`, который измеряет время выполнения блока кода.
#
# Пример использования:
#
# ```python
# with Timer():
#     time.sleep(1)
# ```
#
# После выхода из блока должно печататься время выполнения.

# %%
# ???????

# %% [markdown]
# ### 4. Контекстный менеджер для логов
#
# Напиши класс `LogBlock`, который при входе в блок печатает:
#
# ```text
# Начинаем: <название>
# ```
#
# а при выходе:
#
# ```text
# Закончили: <название>
# ```
#
# Название передается в конструктор.

# %%
# ???????

# %% [markdown]
# ### 5. `contextlib.contextmanager`
#
# Сделай контекстный менеджер `temporary_message(message)` через `@contextmanager`.
#
# Он должен:
#
# - перед блоком печатать `START: <message>`;
# - после блока печатать `END: <message>`;
# - печатать `END` даже если внутри блока произошла ошибка.

# %%
# ???????

# %% [markdown]
# ## Функции как объекты, `lambda`, `sorted`, `map`, `filter`

# %% [markdown]
# ### 1. Функция в переменной
#
# Напиши функцию `multiply_by_two(x)`, затем сохрани ее в переменную `operation`.
#
# Вызови `operation(10)` и проверь, что получилось `20`.

# %%
# ???????

# %% [markdown]
# ### 2. Передача функции аргументом
#
# Напиши функцию `apply_operation(numbers, operation)`, которая принимает список чисел и функцию, применяет функцию к каждому числу и возвращает новый список.
#
# Пример:
#
# ```python
# apply_operation([1, 2, 3], lambda x: x ** 2)
# ```
#
# должен вернуть `[1, 4, 9]`.

# %%
# ???????

# %% [markdown]
# ### 3. Сортировка слов
#
# Дан список:
#
# ```python
# words = ["python", "ai", "notebook", "code", "lambda"]
# ```
#
# Отсортируй его:
#
# - по длине слова;
# - по последней букве;
# - по количеству букв `o` в слове.

# %%
# ???????

# %% [markdown]
# ### 4. Фильтр пользователей
#
# Дан список словарей:
#
# ```python
# users = [
#     {"name": "Ann", "age": 17},
#     {"name": "Bob", "age": 25},
#     {"name": "Kate", "age": 31},
#     {"name": "Tom", "age": 15},
# ]
# ```
#
# Через `filter` оставь только совершеннолетних пользователей.

# %%
# ???????

# %% [markdown]
# ### 5. `map` против comprehension
#
# Дан список температур в градусах Цельсия:
#
# ```python
# celsius = [0, 10, 20, 30, 100]
# ```
#
# Получить список температур в Фаренгейтах по формуле:
#
# ```python
# fahrenheit = celsius * 9 / 5 + 32
# ```
#
# Сделай два решения:
#
# - через `map`;
# - через list comprehension.

# %%
# ???????

# %% [markdown]
# ## Декораторы

# %% [markdown]
# ### 1. Декоратор `debug`
#
# Напиши декоратор `debug`, который печатает:
#
# - имя вызываемой функции;
# - позиционные аргументы;
# - именованные аргументы;
# - результат функции.
#
# Проверь на функции `add(a, b)`.

# %%
# ???????

# %% [markdown]
# ### 2. Декоратор `timer`
#
# Напиши декоратор `timer`, который измеряет время выполнения функции.
#
# Проверь на функции, внутри которой есть `time.sleep(1)`.

# %%
# ???????

# %% [markdown]
# ### 3. Декоратор `repeat`
#
# Напиши декоратор `repeat_twice`, который вызывает функцию два раза подряд.
#
# Пример:
#
# ```python
# @repeat_twice
# def say_hi():
#     print("hi")
# ```
#
# `say_hi()` должен напечатать `hi` два раза.

# %%
# ???????

# %% [markdown]
# ### 4. Проверка аргументов
#
# Напиши декоратор `only_positive`, который разрешает вызывать функцию только с положительными числовыми аргументами.
#
# Если есть ноль или отрицательное число, декоратор должен выбрасывать `ValueError`.
#
# Проверь на функции деления:
#
# ```python
# def divide(a, b):
#     return a / b
# ```

# %%
# ???????

# %% [markdown]
# ### 5. `functools.wraps`
#
# Напиши декоратор `debug` сначала без `@wraps`, потом с `@wraps`.
#
# Проверь разницу:
#
# ```python
# print(function.__name__)
# ```
#
# Объясни в комментарии, почему `@wraps` полезен.

# %%
# ???????

# %% [markdown]
# ## Итераторы

# %% [markdown]
# ### 1. Ручной обход списка
#
# Создай список `[10, 20, 30]`, получи из него итератор через `iter()` и три раза вызови `next()`.
#
# Потом вызови `next()` четвертый раз и посмотри, какая ошибка возникнет.

# %%
# ???????

# %% [markdown]
# ### 2. Класс `Countdown`
#
# Напиши итератор `Countdown`, который принимает число `start` и выдает числа от `start` до `1`.
#
# Пример:
#
# ```python
# list(Countdown(5))
# ```
#
# должен вернуть `[5, 4, 3, 2, 1]`.

# %%
# ???????

# %% [markdown]
# ### 3. Класс `EvenNumbers`
#
# Напиши итератор `EvenNumbers`, который принимает список чисел и возвращает только четные.
#
# Пример:
#
# ```python
# list(EvenNumbers([1, 2, 3, 4, 5, 6]))
# ```
#
# должен вернуть `[2, 4, 6]`.

# %%
# ???????

# %% [markdown]
# ### 4. Одноразовость итератора
#
# Создай итератор:
#
# ```python
# iterator = iter([1, 2, 3])
# ```
#
# Сначала выполни `list(iterator)`, потом еще раз `list(iterator)`.
#
# Объясни в комментарии, почему второй список пустой.

# %%
# ???????

# %% [markdown]
# ### 5. Итератор по строкам файла
#
# Создай файл `lines.txt` с несколькими строками.
#
# Открой файл через `with open(...)` и пройди по нему в цикле `for`.
#
# Проверь, что файл можно перебирать построчно, не вызывая `.readlines()`.

# %%
# ???????

# %% [markdown]
# ## Генераторы `yield`

# %% [markdown]
# ### 1. Генератор `count_up_to`
#
# Напиши генератор `count_up_to(n)`, который выдает числа от `1` до `n`.
#
# Проверь:
#
# ```python
# list(count_up_to(5)) == [1, 2, 3, 4, 5]
# ```

# %%
# ???????

# %% [markdown]
# ### 2. Генератор четных чисел
#
# Напиши генератор `even_numbers(n)`, который выдает четные числа от `0` до `n` включительно.
#
# Пример:
#
# ```python
# list(even_numbers(8))
# ```
#
# должен вернуть `[0, 2, 4, 6, 8]`.

# %%
# ???????

# %% [markdown]
# ### 3. Fibonacci
#
# Напиши генератор `fibonacci(n)`, который выдает первые `n` чисел Фибоначчи.
#
# Проверка:
#
# ```python
# assert list(fibonacci(7)) == [0, 1, 1, 2, 3, 5, 8]
# ```

# %%
# ???????

# %% [markdown]
# ### 4. Генератор строк файла
#
# Напиши генератор `read_non_empty_lines(path)`, который открывает файл и выдает только непустые строки без символа переноса строки в конце.
#
# Подсказка: используй `.strip()`.

# %%
# ???????

# %% [markdown]
# ### 5. Бесконечный генератор
#
# Напиши генератор `infinite_counter()`, который бесконечно выдает числа `1, 2, 3, ...`.
#
# Проверь его через `next()`, но не превращай в `list()`.

# %%
# ???????

# %% [markdown]
# ## Генераторные выражения

# %% [markdown]
# ### 1. Сумма квадратов
#
# Посчитай сумму квадратов чисел от `1` до `1000` через генераторное выражение.
#
# Используй `sum(...)`.

# %%
# ???????

# %% [markdown]
# ### 2. Сумма квадратов нечетных
#
# Посчитай сумму квадратов всех нечетных чисел от `1` до `1_000_000`.
#
# Не создавай промежуточный список.

# %%
# ???????

# %% [markdown]
# ### 3. Поиск длинных слов
#
# Дан список слов. Через генераторное выражение создай генератор слов длиной больше `5`.
#
# Проверь его через:
#
# ```python
# for word in long_words:
#     print(word)
# ```

# %%
# ???????

# %% [markdown]
# ### 4. Память списка и генератора
#
# Создай:
#
# ```python
# list_comp = [x ** 2 for x in range(100000)]
# gen_comp = (x ** 2 for x in range(100000))
# ```
#
# Сравни размер через `sys.getsizeof`.

# %%
# ???????

# %% [markdown]
# ### 5. Одноразовость генератора
#
# Создай генератор:
#
# ```python
# numbers = (x for x in range(3))
# ```
#
# Выполни `list(numbers)` два раза подряд.
#
# Объясни в комментарии, почему второй результат пустой.

# %%
# ???????

# %% [markdown]
# ## `if __name__ == "__main__"`

# %% [markdown]
# ### 1. Первый `main`
#
# Создай файл `script.py`.
#
# В нем напиши функцию `main()`, которая печатает `"Запуск программы"`.
#
# Вызови `main()` только внутри:
#
# ```python
# if __name__ == "__main__":
#     main()
# ```

# %%
# ???????

# %% [markdown]
# ### 2. Импорт без запуска
#
# Создай файл `utils.py` с функцией `add(a, b)` и печатью внутри блока `if __name__ == "__main__"`.
#
# Создай файл `main.py`, импортируй `add` из `utils.py`.
#
# Проверь, что код внутри блока `if __name__ == "__main__"` при импорте не выполнился.

# %%
# ???????

# %% [markdown]
# ### 3. Demo-код в модуле
#
# Создай модуль `text_utils.py` с функцией `normalize_text(text)`, которая приводит строку к нижнему регистру и убирает пробелы по краям.
#
# В блоке `if __name__ == "__main__"` добавь несколько демонстрационных вызовов.

# %%
# ???????

# %% [markdown]
# ### 4. Мини CLI
#
# Создай файл `calculator.py`.
#
# В нем должны быть функции `add`, `subtract`, `multiply`, `divide`.
#
# В `main()` спроси у пользователя два числа и операцию, затем выведи результат.
#
# Запуск `main()` должен быть только под `if __name__ == "__main__"`.

# %%
# ???????

# %% [markdown]
# ### 5. Проверка `__name__`
#
# Создай файл `name_check.py`, который печатает:
#
# ```python
# print(__name__)
# ```
#
# Запусти его напрямую, затем импортируй из другого файла.
#
# Сравни, что выводится в обоих случаях.

# %%
# ???????
